# %% [markdown]
# # Direct download from insee.fr

# %% [markdown]
# **TO BE COMPLETED**
#
# The sources available in this package are all listed
# [here](https://inseefrlab.github.io/DoReMIFaSol/reference/liste_donnees.html)
#
# The following packages are necessary to execute the following examples:

# %%
import pynsee.download
import pandas as pd

# %% [markdown]
# ## Find years available for a data source
#
# Let's assume we are interested in French census data (codename: `RP_LOGEMENT`).
#
# All datasets matching a given codename can be retrieved using `millesimesDisponibles`.
# They are returned as a dict type and are easily converted into a standard pandas table:

# %%
pd.DataFrame(pynsee.download.millesimesDisponibles("RP_LOGEMENT"))
# Out:
#                                                   RP_LOGEMENT_2010  \
# nom                                                    RP_LOGEMENT
# libelle          Données du Recensement de Population, table lo...
# date_ref                                                2010-01-01
# collection                                                      RP
# lien             https://www.insee.fr/fr/statistiques/fichier/2...
# type                                                           csv
# zip                                                           True
# big_zip                                                       True
# fichier_donnees                                 FD_LOGEMT_2010.txt
# fichier_meta                                MOD_FD_LOGEMT_2010.txt
# separateur                                                       ;
# api_rest                                                     False
# md5                               d18c9353693226a9b8ce3a9d2deb2a64
# size                                                     423577561
# label_col                                                      NaN
# type_col                                                       NaN
# long_col                                                       NaN
# val_col                                                        NaN
#
#                                                   RP_LOGEMENT_2011  \
# nom                                                    RP_LOGEMENT
# libelle          Données du Recensement de Population, table lo...
# date_ref                                                2011-01-01
# collection                                                      RP
# lien             https://www.insee.fr/fr/statistiques/fichier/2...
# type                                                           csv
# zip                                                           True
# big_zip                                                       True
# fichier_donnees                                 FD_LOGEMT_2011.txt
# fichier_meta                                MOD_FD_LOGEMT_2011.txt
# separateur                                                       ;
# api_rest                                                     False
# md5                               2e1a835ca6779d139039cdfd9ed05ce3
# size                                                     348979606
# label_col                                                      NaN
# type_col                                                       NaN
# long_col                                                       NaN
# val_col                                                        NaN
#
#                                                   RP_LOGEMENT_2012  \
# nom                                                    RP_LOGEMENT
# libelle          Données du Recensement de Population, table lo...
# date_ref                                                2012-01-01
# collection                                                      RP
# lien             https://www.insee.fr/fr/statistiques/fichier/1...
# type                                                           csv
# zip                                                           True
# big_zip                                                       True
# fichier_donnees                                 FD_LOGEMT_2012.txt
# fichier_meta                                   MOD_LOGEMT_2012.txt
# separateur                                                       ;
# api_rest                                                     False
# md5                               3af5722228764d577202a2bcbdec17d1
# size                                                     351221394
# label_col                                                      NaN
# type_col                                                       NaN
# long_col                                                       NaN
# val_col                                                        NaN
#
#                                                   RP_LOGEMENT_2013  \
# nom                                                    RP_LOGEMENT
# libelle          Données du Recensement de Population, table lo...
# date_ref                                                2013-01-01
# collection                                                      RP
# lien             https://www.insee.fr/fr/statistiques/fichier/2...
# type                                                           csv
# zip                                                           True
# big_zip                                                       True
# fichier_donnees                                 FD_LOGEMT_2013.txt
# fichier_meta                                   MOD_LOGEMT_2013.txt
# separateur                                                       ;
# api_rest                                                     False
# md5                               67bedef4331c7cabff7e1f993179a864
# size                                                     369149255
# label_col                                                      NaN
# type_col                                                       NaN
# long_col                                                       NaN
# val_col                                                        NaN
#
#                                                   RP_LOGEMENT_2014  \
# nom                                                    RP_LOGEMENT
# libelle          Données du Recensement de Population, table lo...
# date_ref                                                2014-01-01
# collection                                                      RP
# lien             https://www.insee.fr/fr/statistiques/fichier/3...
# type                                                           csv
# zip                                                           True
# big_zip                                                       True
# fichier_donnees                                 FD_LOGEMT_2014.txt
# fichier_meta                                   MOD_LOGEMT_2014.txt
# separateur                                                       ;
# api_rest                                                     False
# md5                               cc898ab41ff118d248c07f5846d0a705
# size                                                     378712365
# label_col                                                      NaN
# type_col                                                       NaN
# long_col                                                       NaN
# val_col                                                        NaN
#
#                                                   RP_LOGEMENT_2015  \
# nom                                                    RP_LOGEMENT
# libelle          Données du Recensement de Population, table lo...
# date_ref                                                2015-01-01
# collection                                                      RP
# lien             https://www.insee.fr/fr/statistiques/fichier/3...
# type                                                           csv
# zip                                                           True
# big_zip                                                       True
# fichier_donnees                                 FD_LOGEMT_2015.txt
# fichier_meta                                   MOD_LOGEMT_2015.txt
# separateur                                                       ;
# api_rest                                                     False
# md5                               ff978cb04a4f172ea69f06748b2b51d5
# size                                                     386529234
# label_col                                                      NaN
# type_col                                                       NaN
# long_col                                                       NaN
# val_col                                                        NaN
#
#                                                   RP_LOGEMENT_2016  \
# nom                                                    RP_LOGEMENT
# libelle          Données du Recensement de Population, table lo...
# date_ref                                                2016-01-01
# collection                                                      RP
# lien             https://www.insee.fr/fr/statistiques/fichier/4...
# type                                                           csv
# zip                                                           True
# big_zip                                                       True
# fichier_donnees                                 FD_LOGEMT_2016.csv
# fichier_meta                                varmod_LOGEMT_2016.csv
# separateur                                                       ;
# api_rest                                                     False
# md5                               05b8f24d9c3d86e0f797526e7ee50b04
# size                                                     390969725
# label_col        {'COMMUNE': 'Département et commune du lieu de...
# type_col         {'COMMUNE': 'character', 'ARM': 'character', '...
# long_col         {'COMMUNE': 5.0, 'ARM': 5.0, 'IRIS': 9.0, 'ACH...
# val_col          {'ACHL': {'A11': 'Avant 1919', 'A12': 'De 1919...
#
#                                                   RP_LOGEMENT_2017
# nom                                                    RP_LOGEMENT
# libelle          Données du Recensement de Population, table lo...
# date_ref                                                2017-01-01
# collection                                                      RP
# lien             https://www.insee.fr/fr/statistiques/fichier/4...
# type                                                           csv
# zip                                                           True
# big_zip                                                       True
# fichier_donnees                                 FD_LOGEMT_2017.csv
# fichier_meta                                varmod_LOGEMT_2017.csv
# separateur                                                       ;
# api_rest                                                     False
# md5                               a5dfdb7063c0ea60b250de7a573bb370
# size                                                     390897768
# label_col                                                      NaN
# type_col                                                       NaN
# long_col                                                       NaN
# val_col                                                        NaN

# %% [markdown]
# ## Request dataset from insee.fr website
#
# The easiest approach is to use `telechargerDonnees`
